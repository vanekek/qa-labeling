# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(
    "/Users/alfa/Desktop/Projects/mlops_2025/qa_labeling/data_raw/train.csv"
)

# %%
df
# Out:
#       qa_id                                     question_title  \
# 0         0  What am I losing when using extension tubes in...
# 1         1  What is the distinction between a city and a s...
# 2         2  Maximum protusion length for through-hole comp...
# 3         3              Can an affidavit be used in Beit Din?
# 4         5       How do you make a binary image in Photoshop?
# ...     ...                                                ...
# 6074   9642               Using a ski helmet for winter biking
# 6075   9643  Adjustment to road bike brakes for high grade ...
# 6076   9645  Suppress 'file truncated' messages when using ...
# 6077   9646           When should a supervisor be a co-author?
# 6078   9647  Why are there so many different types of screw...
#
#                                           question_body question_user_name  \
# 0     After playing around with macro photography on...               ysap
# ...

# %%
df_new = df.copy(deep=True)

# %%
df_train, df_val = train_test_split(df_new, test_size=0.15, random_state=42)

# %%
path_to_save = "../data_raw/val.csv"
df_val.to_csv(path_to_save, index=False)

# %%
path_to_save = "../data_raw/train.csv"
df_train.to_csv(path_to_save, index=False)

# %%
df_train
# Out:
#       qa_id                                     question_title  \
# 179     279    Set natbib options after loading natbib package
# 5477   8696                           Was Erica Albright real?
# 4510   7148  Which achievements are missable if sharing Sky...
# 1743   2755  Will a site URL with repeating keywords get pe...
# 4570   7241                           What is the Gorel Hagra?
# ...     ...                                                ...
# 3772   6005            Is apt-get upgrade a dangerous command?
# 5191   8247                 lxc-create hangs and finally fails
# 5226   8308  Noise canceling headphones make strange sound ...
# 5390   8565  Apple Push Notification - all messages get sen...
# 860    1368                   Two sets came to an intersection
#
#                                           question_body question_user_name  \
# 179   Is it possible to set (or change) the natbib p...               v_2e
# ...
